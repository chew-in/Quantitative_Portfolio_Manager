# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os

# %% [markdown]
# 1. Efficient Data Loading - load using `pandas` with chunking.
# 1. Data Exploration -

# %% [markdown]
# # Data Understanding and Processing

# %% [markdown]
# ## Data loading
# - The data_date column is converted to a datetime format for proper merging.

# %%
# %%time
# improved code
# Define the directory where the CSV files are located
data_dir = "../data/raw/"

# List of dataset files
dataset_files = [f"data_set_{i}.csv" for i in range(1, 12)]
risk_factor_files = ["risk_factors_1.csv", "risk_factors_2.csv"]
security_ref_files = ["security_reference_data_w_ret1d_1.csv", "security_reference_data_w_ret1d_2.csv"]

# Function to load data with chunksize
def load_data_with_chunks(file_path, chunksize=100000):
    chunks = []
    for chunk in pd.read_csv(file_path, chunksize=chunksize):
        # Force the conversion of 'data_date' from integer to datetime
        chunk['data_date'] = pd.to_datetime(chunk['data_date'], format='%Y%m%d')
        chunks.append(chunk)
    return pd.concat(chunks, ignore_index=True)

# Load datasets into a dictionary for easy access
datasets = {file: load_data_with_chunks(os.path.join(data_dir, file)) for file in dataset_files}
risk_factors = {file: load_data_with_chunks(os.path.join(data_dir, file)) for file in risk_factor_files}
security_reference_data = {file: load_data_with_chunks(os.path.join(data_dir, file)) for file in security_ref_files}
# Out:
# CPU times: user 23.5 s, sys: 7.04 s, total: 30.6 s
# Wall time: 41.1 s

# %% [markdown]
# ## Data Exploration
# - Basic statistics
# - Number of unique stock value, missing values before cleaning

# %%
def explore_dataframe(df, name):
    """
    Prints basic statistics and counts for the given DataFrame.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to explore.
    name (str): The name of the DataFrame (for printing).
    """
    print("#" * 50)
    print(f"Exploring {name}")
    print(df.info())
    print(df.describe())
    print("Missing values in each column:")
    print(df.isna().sum())  # Check for missing values
    
    # Count of unique trading dates
    unique_dates_count = df['data_date'].nunique()
    print(f"Count of unique trading dates (data_date): {unique_dates_count}")
    
    # Count of unique security IDs
    if 'security_id' in df.columns:
        unique_stocks_count = df['security_id'].nunique()
        print(f"Count of unique stocks (security_id): {unique_stocks_count}")
    else:
        print("No security_id column in this DataFrame.")

# %%
# Explore Security Reference Data
for key, df in security_reference_data.items():
    explore_dataframe(df, key)
# Out:
# ##################################################
# Exploring security_reference_data_w_ret1d_1.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4311675 entries, 0 to 4311674
# Data columns (total 7 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   data_date            datetime64[ns]
#  1   security_id          int64
#  2   close_price          float64
#  3   volume               float64
#  4   group_id             int64
#  5   in_trading_universe  object
#  6   ret1d                float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 230.3+ MB
# None
#                            data_date   security_id   close_price  \
# count                        4311675  4.311675e+06  4.311675e+06
# mean   2011-12-16 07:23:10.842770432  1.032505e+08  2.750957e+01
# min              2010-01-04 00:00:00  7.790100e+04  1.000100e+00
# 25%              2010-12-06 00:00:00  2.377501e+06  5.860000e+00
# 50%              2011-12-05 00:00:00  5.025401e+06  1.494000e+01
# 75%              2012-12-26 00:00:00  7.973201e+06  3.208000e+01
# max              2013-12-31 00:00:00  1.116564e+09  1.417680e+05
# std                              NaN  3.102355e+08  5.750639e+02
#
#              volume      group_id         ret1d
# count  4.311675e+06  4.311675e+06  4.308118e+06
# mean   1.292230e+06  3.234680e+07  1.353188e-03
# min    0.000000e+00  1.010101e+07 -8.562033e-01
# 25%    3.775450e+04  2.030301e+07 -1.209734e-02
# 50%    1.997830e+05  3.520101e+07  0.000000e+00
# 75%    8.165520e+05  4.040205e+07  1.273887e-02
# max    1.864159e+09  5.510501e+07  1.099000e+03
# std    7.616967e+06  1.186244e+07  5.319396e-01
# Missing values in each column:
# data_date                 0
# security_id               0
# close_price               0
# volume                    0
# group_id                  0
# in_trading_universe       0
# ret1d                  3557
# dtype: int64
# Count of unique trading dates (data_date): 1006
# Count of unique stocks (security_id): 6582
# ##################################################
# Exploring security_reference_data_w_ret1d_2.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4488340 entries, 0 to 4488339
# Data columns (total 7 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   data_date            datetime64[ns]
#  1   security_id          int64
#  2   close_price          float64
#  3   volume               float64
#  4   group_id             int64
#  5   in_trading_universe  object
#  6   ret1d                float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 239.7+ MB
# None
#                            data_date   security_id   close_price  \
# count                        4488340  4.488340e+06  4.488340e+06
# mean   2015-12-29 13:31:55.840957696  2.827818e+08  3.402144e+01
# min              2014-01-02 00:00:00  1.031000e+03  1.000100e+00
# 25%              2014-12-29 00:00:00  2.884601e+06  7.810000e+00
# 50%              2015-12-24 00:00:00  6.000501e+06  1.910000e+01
# 75%              2016-12-27 00:00:00  1.077862e+09  4.186000e+01
# max              2017-12-29 00:00:00  1.118042e+09  4.258600e+03
# std                              NaN  4.771723e+08  6.183037e+01
#
#              volume      group_id         ret1d
# count  4.488340e+06  4.488340e+06  4.483043e+06
# mean   1.150349e+06  3.307547e+07  6.152269e-04
# min    1.000000e+00  1.010101e+07 -9.651200e-01
# 25%    5.507900e+04  2.520101e+07 -1.089508e-02
# 50%    2.474870e+05  3.520101e+07  0.000000e+00
# 75%    8.875792e+05  4.040204e+07  1.096145e-02
# max    6.182376e+08  6.010204e+07  9.999999e+01
# std    3.789807e+06  1.194376e+07  6.603923e-02
# Missing values in each column:
# data_date                 0
# security_id               0
# close_price               0
# volume                    0
# group_id                  0
# in_trading_universe       0
# ret1d                  5297
# dtype: int64
# Count of unique trading dates (data_date): 1007
# Count of unique stocks (security_id): 5953

# %%
# Explore Risk Factors
for key, df in risk_factors.items():
    explore_dataframe(df, key)
# Out:
# ##################################################
# Exploring risk_factors_1.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4311675 entries, 0 to 4311674
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   data_date    datetime64[ns]
#  1   security_id  int64
#  2   rf1          float64
#  3   rf2          float64
#  4   rf3          float64
#  5   rf4          float64
#  6   rf5          float64
#  7   rf6          float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 263.2 MB
# None
#                            data_date   security_id           rf1  \
# count                        4311675  4.311675e+06  4.311675e+06
# mean   2011-12-16 07:23:10.842770432  1.032505e+08  9.260416e-02
# min              2010-01-04 00:00:00  7.790100e+04 -2.696000e+00
# 25%              2010-12-06 00:00:00  2.377501e+06 -7.210000e-01
# 50%              2011-12-05 00:00:00  5.025401e+06  7.900000e-02
# 75%              2012-12-26 00:00:00  7.973201e+06  8.880000e-01
# max              2013-12-31 00:00:00  1.116564e+09  3.700000e+00
# std                              NaN  3.102355e+08  1.169601e+00
#
#                 rf2           rf3           rf4           rf5           rf6
# count  4.311675e+06  4.311675e+06  4.311675e+06  4.311675e+06  4.311675e+06
# mean  -2.275420e-01  6.147553e-01  4.506368e-01  5.257731e-02 -5.012062e-01
# min   -3.169000e+00 -2.796000e+00 -2.810000e+00 -2.976000e+00 -3.394000e+00
# 25%   -8.500000e-01 -4.420000e-01 -4.310000e-01 -6.720000e-01 -1.100000e+00
# 50%   -1.720000e-01  3.110000e-01  2.640000e-01 -3.000000e-02 -2.940000e-01
# 75%    4.340000e-01  1.729000e+00  1.195000e+00  6.790000e-01  2.270000e-01
# max    2.946000e+00  2.866000e+00  3.278000e+00  2.976000e+00  2.740000e+00
# std    1.170309e+00  1.293968e+00  1.202208e+00  1.123318e+00  1.272883e+00
# Missing values in each column:
# data_date      0
# security_id    0
# rf1            0
# rf2            0
# rf3            0
# rf4            0
# rf5            0
# rf6            0
# dtype: int64
# Count of unique trading dates (data_date): 1006
# Count of unique stocks (security_id): 6582
# ##################################################
# Exploring risk_factors_2.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4488340 entries, 0 to 4488339
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   data_date    datetime64[ns]
#  1   security_id  int64
#  2   rf1          float64
#  3   rf2          float64
#  4   rf3          float64
#  5   rf4          float64
#  6   rf5          float64
#  7   rf6          float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 273.9 MB
# None
#                            data_date   security_id           rf1  \
# count                        4488340  4.488340e+06  4.488340e+06
# mean   2015-12-29 13:31:55.840957696  2.827818e+08  3.156161e-02
# min              2014-01-02 00:00:00  1.031000e+03 -3.068000e+00
# 25%              2014-12-29 00:00:00  2.884601e+06 -7.260000e-01
# 50%              2015-12-24 00:00:00  6.000501e+06  3.700000e-02
# 75%              2016-12-27 00:00:00  1.077862e+09  7.920000e-01
# max              2017-12-29 00:00:00  1.118042e+09  3.634000e+00
# std                              NaN  4.771723e+08  1.168258e+00
#
#                 rf2           rf3           rf4           rf5           rf6
# count  4.488340e+06  4.488340e+06  4.488340e+06  4.488340e+06  4.488340e+06
# mean  -3.561001e-01  5.183900e-01  4.825143e-01 -7.597362e-02 -5.063054e-01
# min   -3.049000e+00 -2.893000e+00 -2.818000e+00 -2.900000e+00 -3.352000e+00
# 25%   -9.540000e-01 -4.800000e-01 -3.800000e-01 -7.160000e-01 -1.190000e+00
# 50%   -2.380000e-01  2.220000e-01  2.980000e-01 -9.000000e-02 -1.980000e-01
# 75%    3.190000e-01  1.471000e+00  1.236000e+00  5.200000e-01  2.900000e-01
# max    2.824000e+00  3.034000e+00  3.276000e+00  2.883000e+00  2.794000e+00
# std    1.156004e+00  1.244712e+00  1.188191e+00  1.103113e+00  1.297041e+00
# Missing values in each column:
# data_date      0
# security_id    0
# rf1            0
# rf2            0
# rf3            0
# rf4            0
# rf5            0
# rf6            0
# dtype: int64
# Count of unique trading dates (data_date): 1007
# Count of unique stocks (security_id): 5953

# %%
# Explore Datasets
for key, df in datasets.items():
    explore_dataframe(df, key)
# Out:
# ##################################################
# Exploring data_set_1.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127266 entries, 0 to 127265
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    127266 non-null  datetime64[ns]
#  1   security_id  127266 non-null  int64
#  2   d1           122478 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.9 MB
# None
#                            data_date   security_id            d1
# count                         127266  1.272660e+05  1.224780e+05
# mean   2014-01-09 08:56:26.997313280  1.854502e+08  2.464821e+03
# min              2010-01-04 00:00:00  1.031000e+03 -1.470070e+07
# 25%              2011-12-07 00:00:00  2.552401e+06 -5.024750e+00
# 50%              2014-02-18 00:00:00  5.345401e+06  3.731000e+00
# 75%              2016-02-05 00:00:00  8.688701e+06  4.000000e+01
# max              2017-12-29 00:00:00  1.117808e+09  1.001120e+07
# std                              NaN  4.057012e+08  1.435562e+05
# Missing values in each column:
# data_date         0
# security_id       0
# d1             4788
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_2.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127266 entries, 0 to 127265
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    127266 non-null  datetime64[ns]
#  1   security_id  127266 non-null  int64
#  2   d2           112630 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.9 MB
# None
#                            data_date   security_id            d2
# count                         127266  1.272660e+05  1.126300e+05
# mean   2014-01-09 08:56:26.997313280  1.854502e+08  6.189699e+03
# min              2010-01-04 00:00:00  1.031000e+03 -9.705380e+06
# 25%              2011-12-07 00:00:00  2.552401e+06 -6.155000e+00
# 50%              2014-02-18 00:00:00  5.345401e+06  2.105500e+01
# 75%              2016-02-05 00:00:00  8.688701e+06  1.530857e+02
# max              2017-12-29 00:00:00  1.117808e+09  2.178200e+07
# std                              NaN  4.057012e+08  2.594529e+05
# Missing values in each column:
# data_date          0
# security_id        0
# d2             14636
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_3.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254532 entries, 0 to 254531
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    254532 non-null  datetime64[ns]
#  1   security_id  254532 non-null  int64
#  2   d3           199866 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 5.8 MB
# None
#                            data_date   security_id             d3
# count                         254532  2.545320e+05  199866.000000
# mean   2014-01-09 08:56:26.997312256  1.854502e+08       0.124435
# min              2010-01-04 00:00:00  1.031000e+03    -356.424242
# 25%              2011-12-07 00:00:00  2.552401e+06      -0.025051
# 50%              2014-02-18 00:00:00  5.345401e+06       0.028785
# 75%              2016-02-05 00:00:00  8.688701e+06       0.063930
# max              2017-12-29 00:00:00  1.117808e+09   12051.111111
# std                              NaN  4.057004e+08      38.229641
# Missing values in each column:
# data_date          0
# security_id        0
# d3             54666
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_4.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254532 entries, 0 to 254531
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    254532 non-null  datetime64[ns]
#  1   security_id  254532 non-null  int64
#  2   d4           245186 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 5.8 MB
# None
#                            data_date   security_id             d4
# count                         254532  2.545320e+05  245186.000000
# mean   2014-01-09 08:56:26.997312512  1.854502e+08      -0.537764
# min              2010-01-04 00:00:00  1.031000e+03  -15928.100000
# 25%              2011-12-07 00:00:00  2.552401e+06       0.051700
# 50%              2014-02-18 00:00:00  5.345401e+06       4.113400
# 75%              2016-02-05 00:00:00  8.688701e+06       9.731300
# max              2017-12-29 00:00:00  1.117808e+09     347.040000
# std                              NaN  4.057004e+08      86.486701
# Missing values in each column:
# data_date         0
# security_id       0
# d4             9346
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_5.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127266 entries, 0 to 127265
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    127266 non-null  datetime64[ns]
#  1   security_id  127266 non-null  int64
#  2   d5           112203 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.9 MB
# None
#                            data_date   security_id             d5
# count                         127266  1.272660e+05  112203.000000
# mean   2014-01-09 08:56:26.997313280  1.854502e+08       0.026117
# min              2010-01-04 00:00:00  1.031000e+03     -87.121212
# 25%              2011-12-07 00:00:00  2.552401e+06      -0.002273
# 50%              2014-02-18 00:00:00  5.345401e+06       0.012174
# 75%              2016-02-05 00:00:00  8.688701e+06       0.022500
# max              2017-12-29 00:00:00  1.117808e+09    2589.259259
# std                              NaN  4.057012e+08       7.781675
# Missing values in each column:
# data_date          0
# security_id        0
# d5             15063
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_6.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127266 entries, 0 to 127265
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    127266 non-null  datetime64[ns]
#  1   security_id  127266 non-null  int64
#  2   d6           102273 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.9 MB
# None
#                            data_date   security_id             d6
# count                         127266  1.272660e+05  102273.000000
# mean   2014-01-09 08:56:26.997312512  1.854502e+08       0.380598
# min              2010-01-04 00:00:00  1.031000e+03   -4018.240000
# 25%              2011-12-07 00:00:00  2.552401e+06      -0.082500
# 50%              2014-02-18 00:00:00  5.345401e+06       0.020400
# 75%              2016-02-05 00:00:00  8.688701e+06       0.153000
# max              2017-12-29 00:00:00  1.117808e+09   12621.800000
# std                              NaN  4.057012e+08      57.846702
# Missing values in each column:
# data_date          0
# security_id        0
# d6             24993
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_7.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127266 entries, 0 to 127265
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   data_date    127266 non-null  datetime64[ns]
#  1   security_id  127266 non-null  int64
#  2   d7           103140 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.9 MB
# None
#                            data_date   security_id             d7
# count                         127266  1.272660e+05  103140.000000
# mean   2014-01-09 08:56:26.997312512  1.854502e+08       0.054926
# min              2010-01-04 00:00:00  1.031000e+03   -1666.750000
# 25%              2011-12-07 00:00:00  2.552401e+06      -0.179900
# 50%              2014-02-18 00:00:00  5.345401e+06      -0.080200
# 75%              2016-02-05 00:00:00  8.688701e+06      -0.020300
# max              2017-12-29 00:00:00  1.117808e+09    5919.750000
# std                              NaN  4.057012e+08      26.681026
# Missing values in each column:
# data_date          0
# security_id        0
# d7             24126
# dtype: int64
# Count of unique trading dates (data_date): 1992
# Count of unique stocks (security_id): 6522
# ##################################################
# Exploring data_set_8.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8345449 entries, 0 to 8345448
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   data_date    datetime64[ns]
#  1   security_id  int64
#  2   d8           float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 191.0 MB
# None
#                            data_date   security_id            d8
# count                        8345449  8.345449e+06  8.345449e+06
# mean   2014-01-15 01:03:10.669812736  1.935528e+08  2.634151e+06
# min              2010-01-04 00:00:00  1.031000e+03 -3.801000e+03
# 25%              2011-12-28 00:00:00  2.561701e+06  1.922400e+04
# 50%              2014-02-12 00:00:00  5.417701e+06  1.254640e+05
# 75%              2016-01-22 00:00:00  9.578601e+06  5.581680e+05
# max              2017-12-29 00:00:00  1.118042e+09  2.061810e+12
# std                              NaN  4.129920e+08  8.185221e+08
# Missing values in each column:
# data_date      0
# security_id    0
# d8             0
# dtype: int64
# Count of unique trading dates (data_date): 2080
# Count of unique stocks (security_id): 7068
# ##################################################
# Exploring data_set_9.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16176736 entries, 0 to 16176735
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   data_date    datetime64[ns]
#  1   security_id  int64
#  2   d9           float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 370.3 MB
# None
#                            data_date   security_id            d9
# count                       16176736  1.617674e+07  1.617674e+07
# mean   2014-01-14 07:04:14.089331712  1.904351e+08  2.438783e+01
# min              2010-01-04 00:00:00  1.031000e+03  0.000000e+00
# 25%              2011-12-30 00:00:00  2.575801e+06  2.430000e+00
# 50%              2014-02-11 00:00:00  5.401001e+06  8.750000e+00
# 75%              2016-01-20 00:00:00  8.874601e+06  2.931000e+01
# max              2017-12-29 00:00:00  1.117996e+09  6.802500e+03
# std                              NaN  4.102771e+08  3.314039e+01
# Missing values in each column:
# data_date      0
# security_id    0
# d9             0
# dtype: int64
# Count of unique trading dates (data_date): 2013
# Count of unique stocks (security_id): 7373
# ##################################################
# Exploring data_set_10.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3281273 entries, 0 to 3281272
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   data_date    datetime64[ns]
#  1   security_id  int64
#  2   d10          int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 75.1 MB
# None
#                            data_date   security_id           d10
# count                        3281273  3.281273e+06  3.281273e+06
# mean   2014-07-13 12:16:05.421895168  1.638269e+08  5.166481e+02
# min              2010-01-04 00:00:00  1.031000e+03  0.000000e+00
# 25%              2012-10-02 00:00:00  2.369301e+06  1.500000e+01
# 50%              2014-10-09 00:00:00  4.979501e+06  5.900000e+01
# 75%              2016-06-17 00:00:00  8.049301e+06  2.080000e+02
# max              2017-12-29 00:00:00  1.117931e+09  1.558570e+05
# std                              NaN  3.856826e+08  2.631616e+03
# Missing values in each column:
# data_date      0
# security_id    0
# d10            0
# dtype: int64
# Count of unique trading dates (data_date): 2013
# Count of unique stocks (security_id): 3084
# ##################################################
# Exploring data_set_11.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3281273 entries, 0 to 3281272
# Data columns (total 3 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   data_date    datetime64[ns]
#  1   security_id  int64
#  2   d11          float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 75.1 MB
# None
#                            data_date   security_id           d11
# count                        3281273  3.281273e+06  3.281273e+06
# mean   2014-07-13 12:16:05.421895424  1.638269e+08  1.807899e+03
# min              2010-01-04 00:00:00  1.031000e+03  0.000000e+00
# 25%              2012-10-02 00:00:00  2.369301e+06  5.275617e+01
# 50%              2014-10-09 00:00:00  4.979501e+06  2.045406e+02
# 75%              2016-06-17 00:00:00  8.049301e+06  7.262407e+02
# max              2017-12-29 00:00:00  1.117931e+09  6.081597e+05
# std                              NaN  3.856826e+08  9.221158e+03
# Missing values in each column:
# data_date      0
# security_id    0
# d11            0
# dtype: int64
# Count of unique trading dates (data_date): 2013
# Count of unique stocks (security_id): 3084

# %% [markdown]
# ## Data Cleaning
# - Missing values: Drop rows with missing values in data_date and security_id, as these are essential for any merging operations. By analyze missing data - `risk_factors` don't have any NAs. Drop NAs in critical columns and target variables for both `security_reference_data` and `datasets`.
# - Verify that after this step, there is no missing value left.

# %%
# Handling Missing Values Before Merging
# Drop NAs in critical columns for security reference data
for df in security_reference_data.values():
    df.dropna(subset=['data_date', 'security_id'], inplace=True)
    df.dropna(subset=['ret1d'], inplace=True)  # Drop rows with NAs in the target variable

# Drop NAs in datasets
for df in datasets.values():
    df.dropna(subset=['data_date', 'security_id'], inplace=True)
    df.dropna(subset=[col for col in df.columns if 'd' in col], inplace=True)  # Drop rows with NAs in target variables

# %% [markdown]
# ## Data Combination
# - Concatenate Security Reference Data
# - Concatenate Risk Factors
# - Index Setting: Before merging, the code sets the index for both the combined security reference data and risk factors to allow for efficient joins.
# - Merging: Each dataset is merged with the combined security reference data and risk factors using a left join, ensuring that all relevant features are included.
# - Final Combined DataFrame: The final merged_data DataFrame will contain all relevant features from the various datasets and the combined security and risk factor data.

# %%
# %%time
# Concatenate security reference data
combined_security_reference_data = pd.concat(security_reference_data.values(), ignore_index=True)

# Concatenate risk factors
combined_risk_factors = pd.concat(risk_factors.values(), ignore_index=True)

# Set index for combined DataFrames for efficient merging
combined_security_reference_data.set_index(['data_date', 'security_id'], inplace=True)
combined_risk_factors.set_index(['data_date', 'security_id'], inplace=True)
# Out:
# CPU times: user 1.58 s, sys: 3.11 s, total: 4.69 s
# Wall time: 9.12 s

# %%
combined_security_reference_data.head()
# Out:
#                         close_price     volume  group_id in_trading_universe  \
# data_date  security_id
# 2010-01-04 77901              19.99    72728.0  20102010                   N
#            78001              23.77   460537.0  20101010                   Y
#            78401              19.64  1847102.0  20104020                   Y
#            82901               2.80   219545.0  20301010                   N
#            83501               7.90   389291.0  20201060                   N
#
#                            ret1d
# data_date  security_id
# 2010-01-04 77901        0.025654
#            78001        0.034378
#            78401        0.028272
#            82901        0.060606
#            83501        0.085165

# %%
combined_security_reference_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8791161 entries, (Timestamp('2010-01-04 00:00:00'), np.int64(77901)) to (Timestamp('2017-12-29 00:00:00'), np.int64(1118042001))
# Data columns (total 5 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   close_price          float64
#  1   volume               float64
#  2   group_id             int64
#  3   in_trading_universe  object
#  4   ret1d                float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 369.3+ MB

# %%
combined_risk_factors.head()
# Out:
#                           rf1    rf2    rf3    rf4    rf5    rf6
# data_date  security_id
# 2010-01-04 5311701      0.284 -0.500  1.789  2.962 -0.435 -0.314
#            3780701      1.890 -1.330 -0.208  0.775 -0.803 -0.576
#            2297301      0.012  0.217  0.285 -0.151  0.883  0.127
#            83501        1.185  1.195  2.677 -1.485 -1.236 -1.341
#            4159901     -0.335 -2.917  2.548  1.691  0.394 -2.290

# %%
combined_risk_factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8800015 entries, (Timestamp('2010-01-04 00:00:00'), np.int64(5311701)) to (Timestamp('2017-12-29 00:00:00'), np.int64(1115398701))
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   rf1     float64
#  1   rf2     float64
#  2   rf3     float64
#  3   rf4     float64
#  4   rf5     float64
#  5   rf6     float64
# dtypes: float64(6)
# memory usage: 436.8 MB

# %%
# %%time
# Initialize an empty DataFrame for merging datasets
merged_data = pd.DataFrame()

# Merge each dataset with the combined security reference data and risk factors
for file, dataset in datasets.items():
    dataset.set_index(['data_date', 'security_id'], inplace=True)  # Set index for the dataset
    
    # Merge with combined security reference data
    dataset = dataset.join(combined_security_reference_data, how='left')
    
    # Merge with combined risk factors
    dataset = dataset.join(combined_risk_factors, how='left')
    
    # Reset index if needed and store the merged dataset
    dataset.reset_index(inplace=True)
    merged_data = pd.concat([merged_data, dataset], ignore_index=True)

# Now merged_data contains all relevant features from the datasets, security reference data, and risk factors
# Out:
# CPU times: user 2min 44s, sys: 1min 31s, total: 4min 15s
# Wall time: 6min 48s

# %%
merged_data.head()
# Out:
#    data_date  security_id      d1  close_price   volume    group_id  \
# 0 2010-01-04       647001  3.4530        13.80  15552.0  25301040.0
# 1 2010-01-04       696801  1.5820          NaN      NaN         NaN
# 2 2010-01-04      1323901 -0.9449         4.00  10119.0  40101015.0
# 3 2010-01-04      1604101 -9.4220         1.42    709.0  40101015.0
# 4 2010-01-04      1610801 -3.7690         1.50    219.0  40101015.0
#
#   in_trading_universe     ret1d    rf1    rf2  ...  d2  d3  d4  d5  d6  d7  \
# 0                   N -0.044983 -1.335 -0.499  ... NaN NaN NaN NaN NaN NaN
# 1                 NaN       NaN    NaN    NaN  ... NaN NaN NaN NaN NaN NaN
# 2                   N  0.176506 -1.013 -2.508  ... NaN NaN NaN NaN NaN NaN
# 3                   N  0.014286 -1.041 -0.760  ... NaN NaN NaN NaN NaN NaN
# 4                   N  0.041667 -0.036 -2.917  ... NaN NaN NaN NaN NaN NaN
#
#    d8  d9  d10  d11
# 0 NaN NaN  NaN  NaN
# 1 NaN NaN  NaN  NaN
# 2 NaN NaN  NaN  NaN
# 3 NaN NaN  NaN  NaN
# 4 NaN NaN  NaN  NaN
#
# [5 rows x 24 columns]

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32082507 entries, 0 to 32082506
# Data columns (total 24 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   data_date            datetime64[ns]
#  1   security_id          int64
#  2   d1                   float64
#  3   close_price          float64
#  4   volume               float64
#  5   group_id             float64
#  6   in_trading_universe  object
#  7   ret1d                float64
#  8   rf1                  float64
#  9   rf2                  float64
#  10  rf3                  float64
#  11  rf4                  float64
#  12  rf5                  float64
#  13  rf6                  float64
#  14  d2                   float64
#  15  d3                   float64
#  16  d4                   float64
#  17  d5                   float64
#  18  d6                   float64
#  19  d7                   float64
#  20  d8                   float64
#  21  d9                   float64
#  22  d10                  float64
#  23  d11                  float64
# dtypes: datetime64[ns](1), float64(21), int64(1), object(1)
# memory usage: 5.7+ GB

# %% [markdown]
# ## Data Saving

# %%
# Example access to a merged dataset
final_dataset = merged_data['data_set_1.csv']  # Example for the first dataset
